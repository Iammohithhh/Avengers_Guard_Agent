# %%
# In any notebook, run this cell:
import sys
# !{sys.executable} -m pip install --force-reinstall opencv-python numpy
# Out:
# ...
#   Using cached numpy-2.3.3-cp311-cp311-win_amd64.whl.metadata (60 kB)
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.0 MB 445.2 kB/s eta 0:01:28
#    ---------------------------------------- 0.3/39.0 MB 3.0 MB/s eta 0:00:13
#     --------------------------------------- 0.8/39.0 MB 4.7 MB/s eta 0:00:09
#    - -------------------------------------- 1.6/39.0 MB 7.2 MB/s eta 0:00:06
#    -- ------------------------------------- 2.5/39.0 MB 9.9 MB/s eta 0:00:04
#    --- ------------------------------------ 3.3/39.0 MB 11.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.2/39.0 MB 12.1 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.1/39.0 MB 13.1 MB/s eta 0:00:03
# ...

# %%
# Cell 1: Run web server
# %run app.py
# Out:
# 🤖 Active Agent: JARVIS
# 🤖 Active Agent: JARVIS
# 📂 Database loaded: 4 persons
# ✅ Web Guard System initialized
#
# 🦾 Starting Avengers Guard Web Interface...
# ...
# Open browser to: http://localhost:5000
# ...
#
# Client connected
# Client disconnected

# %%
# In a notebook cell, check:
from pathlib import Path
db_file = Path("data/trusted_faces/embeddings/trusted_persons.pkl")
print(f"Database exists: {db_file.exists()}")
print(f"Full path: {db_file.absolute()}")

if db_file.exists():
    import pickle
    with open(db_file, 'rb') as f:
        data = pickle.load(f)
    print(f"Enrolled persons: {len(data)}")
    print(f"Names: {list(data.keys())}")
# Out:
# Database exists: False
# Full path: c:\Users\iammo\OneDrive\Desktop\5th Semester\EE 782\Avengers_Guard_Agent\data\trusted_faces\embeddings\trusted_persons.pkl

# %%
# Search for the database file
import os
from pathlib import Path

for root, dirs, files in os.walk('.'):
    for file in files:
        if file == 'trusted_persons.pkl':
            print(f"Found: {os.path.join(root, file)}")
# Out:
# Found: .\notebooks\data\trusted_faces\embeddings\trusted_persons.pkl
